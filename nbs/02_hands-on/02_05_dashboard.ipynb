# %% [markdown]
# # Dashboards
# > Create centralized, interactive, visual dashboards for your ML experiments

# %% [markdown]
# {{< video https://youtu.be/gnD8BFuyVUA >}}

# %% [markdown]
# :::{.callout-note}
# Click [here](https://docs.wandb.ai/guides/track/app) for more about dashboards.
# :::
